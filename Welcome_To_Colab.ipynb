# %%
import io
import pandas as pd
data = pd.read_csv('/datalab/week1_Climate Risk Vulnerability Mapping/qa.csv')

# %%
# -----------------------------
# STEP 1: Import Libraries
# -----------------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("✅ Libraries Imported Successfully")
# Out:
# ✅ Libraries Imported Successfully

# %%
# -----------------------------
# STEP 3: Basic Exploration
# -----------------------------

# First 5 rows
print("🔹 First 5 Rows of Dataset")
display(data.head())

# Shape of dataset
print("🔹 Dataset Shape (rows, columns):", data.shape)

# Column names
print("🔹 Column Names:", data.columns)
# Out:
# 🔹 First 5 Rows of Dataset
#                                             question  \
# 0  Deniz ekosistemleri üzerindeki okyanus asitleş...
# 1  Ormansızlaşma iklim değişikliğini şiddetlendir...
# 2  İklim değişikliği hayvanların ve böceklerin gö...
# 3  İklim değişikliği doğal afetlerin sıklığını ve...
# 4  Polar buz kapaklarının eritilmesi küresel deni...
#
#                                               answer
# 0  Fazla CO2'nin deniz suyu ile emilmesinden kayn...
# 1  Ormansızlaşma, karbon dioksiti emebilen ve dep...
# 2  İklim değişikliği, çeşitli türlerin habitatlar...
# 3  İklim değişikliği, kasırgalar, kuraklıklar, ya...
# 4  Polar buz kapaklarının eritilmesi, küresel den...
# 🔹 Dataset Shape (rows, columns): (2217, 2)
# 🔹 Column Names: Index(['question', 'answer'], dtype='object')

# %%
# -----------------------------
# STEP 4: Dataset Information
# -----------------------------
print("🔹 Dataset Info:")
data.info()
# Out:
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2217 entries, 0 to 2216
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  2217 non-null   object
#  1   answer    2217 non-null   object
# dtypes: object(2)
# memory usage: 34.8+ KB

# %%
# -----------------------------
# STEP 5: Statistical Summary
# -----------------------------
print("🔹 Statistical Summary:")
display(data.describe())
# Out:
# 🔹 Statistical Summary:
#                                                  question  \
# count                                                2217
# unique                                               2148
# top     İklim değişikliği biyolojik çeşitliliği nasıl ...
# freq                                                    4
#
#                                                    answer
# count                                                2217
# unique                                               2207
# top     Nesiller boyunca aktarılan geleneksel ekolojik...
# freq                                                    2

# %%
# -----------------------------
# STEP 6: Missing Values Check
# -----------------------------
print("🔹 Missing Values in Each Column:")
print(data.isnull().sum())

# (Optional) Visualize missing values
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# 🔹 Missing Values in Each Column:
# question    0
# answer      0
# dtype: int64
